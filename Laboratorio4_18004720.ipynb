# %% [markdown]
# # 1- Parte 1: Numpy:

# %% [markdown]
# # 1) ¿Cuál es el tamaño en bytes de un array de 1000 elementos de tipo booleano?

# %%
import numpy as np

#creamos el array de tipo booleano
array = np.ones(1000, dtype= bool)

#calculamos el tamaño
tamaño= array.nbytes

print(f"El tamaño de bytes de un array de 1000 elementos es {tamaño} bytes")
# Out:
# El tamaño de bytes de un array de 100 elementos es 1000 bytes

# %% [markdown]
# # 2) Cree un array cuyos elementos sean los enteros pares en [1,100] y en orden decreciente. Muestre los 10 últimos por pantalla.

# %%
import numpy as np

#creamos el array 
pares = np.arange(100, 0, -2) #creamos la secuencia para generar de 100 a 2 y excluimos 0

#mostramos el resultado
print(f"los últimos 10 digitos son:", pares[-10:]) # al colocar [-10:] le estamos indicando que muestre los últimos 10 y : que desglose
# Out:
# los últimos 10 digitos son: [20 18 16 14 12 10  8  6  4  2]

# %% [markdown]
# # 3) Dado el array
# # 2 4 5 6
# # 0 3 7 4
# # 8 8 5 2
# # 1 5 6 1

# %%
import numpy as np

array = np.array ([[2, 4, 5, 6],
                   [0, 3, 7, 4],
                   [8, 8, 5, 2],
                   [1, 5, 6, 1]])

#Seleccione con una instrucción el subarray de elementos
#0 3 7 4

array1= array[1,:]

#imprimimos la instruccion 
print("Seleccione la instruccion 0, 3, 7, 4:")
print(array1)

#Después, seleccione el subarray de elementos
#2, 5
array2= array[[0, 0], [0,2]]

#imprime la instruccion 
print("Seleccione la instruccion 2, 5:")
print(array2)

#Después, seleccione el subarray de elementos
#8, 5
array3= array[[2,0], [0,2]]

#imprime la instruccion 
print("Seleccione la instruccion 8, 5:")
print(array3)
# Out:
# Seleccione la instruccion 0, 3, 7, 4:
# [0 3 7 4]
# Seleccione la instruccion 2, 5:
# [2 5]
# Seleccione la instruccion 8, 5:
# [8 5]

# %% [markdown]
# # 4) Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9], obtenga la media aritmética de la diferencia (a-b).

# %%
import numpy as np

a =np.array([1, 4, 2, 7])
b =np.array([1, 3, 2, 9])

#calculamos la diferencia entre los arrays
diferencia = a - b

#calculamos la media aritmetica
media = np.mean(diferencia)

#imprime resultado

print(f"La media aritmetica de, {diferencia} es :", {media})
# Out:
# La media aritmetica de, [ 0  1  0 -2] es : {-0.25}

# %% [markdown]
# # 5) Tengo valores de cordenadas (x, y) en las columnas del array
#
# # 1.33 4.5
# # 30.0 10.7
# # 70.2 0.5

# %%
import numpy as np

coordenadas = np.array([[1.33, 4.5],
                        [30.0, 10.7],
                        [70.2, 0.5]])

#agregamos las nuevas coordenadas
coordenada_nueva = np.array([37.1, -3.6])

#utilizamos la funcion np.vstack para apilar nuestras coordenadas por filas 
nuevas_coordenadas = np.vstack([coordenadas, coordenada_nueva])

#imprime las coordenadas actualizadas
print("Las nuevas coordenadas son:")
print(nuevas_coordenadas)

#imprime las dimensiones
print("Dimensiones del nuevo array")
print(nuevas_coordenadas.shape) #utilizamos el shape para devolver dimensiones de los objetos
# Out:
# Las nuevas coordenadas son:
# [[ 1.33  4.5 ]
#  [30.   10.7 ]
#  [70.2   0.5 ]
#  [37.1  -3.6 ]]
# Dimensiones del nuevo array
# (4, 2)

# %% [markdown]
# # 6) Copie el array del ejercicio anterior.
# # Traspóngalo
# # Agregue ahora dos nuevos pares de coordenadas: (10.8,3.0) y (35.8, 12.0).

# %%
import numpy as np

coordenadas = np.array([[1.33, 4.5],
                        [30.0, 10.7],
                        [70.2, 0.5],
                        [37.1, -3.6]])

#agregamos las nuevas coordenadas
coordenada_nueva = np.array([[10.8, 3.0], 
                             [35.8, 12.0]])

#utilizamos la funcion np.vstack para apilar nuestras coordenadas por filas 
nuevas_coordenadas = np.vstack([coordenadas, coordenada_nueva])

#trasponemos nuestras coordenadas
coordenadas_traspuestas = nuevas_coordenadas.T #utilizamos .T para trasponer de filas a columnas y viceversa

#imprime resultado
print(coordenadas_traspuestas)
# Out:
# [[ 1.33 30.   70.2  37.1  10.8  35.8 ]
#  [ 4.5  10.7   0.5  -3.6   3.   12.  ]]

# %% [markdown]
# # 2. Parte 2: Exploración y Minería de Datos:

# %%
import pandas as pd
##!pip install matplotlib -- yes
import matplotlib.pyplot as plt

# %%
# Cargar el dataset
dataset =pd.read_csv('./nucleospoblacion.csv')
dataset.head()
# Out:
#    FID  OBJECTID     Texto  Poblacion  CodMun Municipio  CodProvin  \
# 0    0         1   Agüimes    29431.0   35002   Agüimes         35
# 1    1         2   Antigua    10458.0   35003   Antigua         35
# 2    2         3  Arrecife    58156.0   35004  Arrecife         35
# 3    3         4    Arucas    36745.0   35006    Arucas         35
# 4    4         5    Gáldar    24473.0   35009    Gáldar         35
#
#     Provincia          X          Y
# 0  Las Palmas -15.446012  27.900542
# 1  Las Palmas -14.013301  28.418966
# 2  Las Palmas -13.551451  28.960649
# 3  Las Palmas -15.521512  28.117496
# 4  Las Palmas -15.654111  28.143873

# %% [markdown]
# # 1) ¿Cuántos Municipios tienen más de 100000 habitantes?

# %%
#realizamos un conteo de poblacion 
poblacion_100000 = dataset[dataset['Poblacion']>100000]

#realizamos un conteo de municipios
municipios = poblacion_100000.shape[0]

#mostramos resultado
print(f"La cantidad de municipios con mas de 100000 habitantes es:{municipios}")
# Out:
# La cantidad de municipios con mas de 100000 habitantes es:62

# %% [markdown]
# # 2) Realice una gráfica de barras sobre la polbación de cada ciudad, ordenela de menor a mayor y responda:

# %%
# !pip install matplotlib -- yes

# %%
import matplotlib.pyplot as plt

#ordenamos la data
dataset_poblacion = dataset.sort_values(by= 'Poblacion', ascending = False)

# Creamos la gráfica de barras
plt.figure(figsize=(10, 6))  # Ajustar el tamaño de la figura
plt.barh(dataset_poblacion['Municipio'], dataset_poblacion['Poblacion'], color='skyblue')  # Gráfico horizontal
plt.xticks(rotation=90) 
plt.tight_layout()
plt.show()

# %% [markdown]
# # a. ¿Cuál es la segunda ciudad más poblada?

# %%
#ordenamos la data
dataset_poblacion = dataset.sort_values(by= 'Poblacion', ascending = False)

# Obtener la segunda ciudad más poblada
segunda_poblada = dataset_poblacion.iloc[1]# con iloc[1] seleccionamos la columna y fila que queremos validar
print(f"La segunda ciudad más poblada es: {segunda_poblada['Municipio']} con una población de {segunda_poblada['Poblacion']}")
# Out:
# La segunda ciudad más poblada es: Barcelona con una población de 1619337.0

# %% [markdown]
# # b. ¿Qué posición ocupa Granada en el ranking de las ciudades más pobladas?

# %%
# Encontrar a Granada
p_granada = dataset_poblacion[dataset_poblacion['Municipio']== 'Granada'].index[0]+1
print(f"Granada esta en la posición: {p_granada} del ranking")
# Out:
# Granada esta en la posición: 273 del ranking

# %% [markdown]
# # 3) ¿Cuántos municipios de La Rioja tienen más de 20,000 habitantes?.

# %%
# filtramos el municipio de La Rioja
la_rioja = dataset[dataset['Provincia'] == 'La Rioja']

#realizamos un conteo de poblacion 
poblacion_20000 = dataset[dataset['Poblacion']>20000]

#realizamos un conteo de municipios
municipios = len(poblacion_20000)

#mostramos resultado
print(f"La cantidad de municipios con mas de 20000 habitantes de la Provincia La Rioja es:{municipios}")
# Out:
# La cantidad de municipios con mas de 20000 habitantes de la Provincia La Rioja es:424

# %% [markdown]
# # 4) ¿Cuál es el municipio situado más al Norte? (Usar el valor de la coordenada "Y" que representa la latitud en grados). Proporcione también la provincia a la que pertenece y su población.

# %%
#ordenamos la data
dataset_poblacion = dataset.sort_values(by= 'Y', ascending = False)
#encontramos el mas alto
mas_al_norte = dataset_poblacion.iloc[0]

nombre = mas_al_norte['Municipio']
provincia = mas_al_norte['Provincia']
poblacion = mas_al_norte['Poblacion']
latitud = mas_al_norte['Y']

#muestra resultados
print(f'El muncipio situado más al Norte es: {nombre}, en la provincia {provincia}, con una población de {poblacion} y una latitud de {latitud}')
# Out:
# El muncipio situado más al Norte es: Viveiro, en la provincia Lugo, con una población de 16211.0 y una latitud de 43.6255783851

# %% [markdown]
# # 5) Obtenga la media, mediana, desviación estándar, valor máximo y valor mínimo de la población de los municipios de la provincia de Granada.

# %%
# Encontrar a Granada
p_granada = dataset_poblacion[dataset_poblacion['Provincia']== 'Granada']

#calculamos las variables

media = p_granada['Poblacion'].mean()
mediana = p_granada['Poblacion'].median()
desv = p_granada['Poblacion'].std()
max= p_granada['Poblacion'].max()
min= p_granada['Poblacion'].min()

#mostramos valores
print(f'Los valores de la provincia de Granada son:')
print(f'media = {media}, mediana = {mediana}, desviación estándar = {desv}, máximo = {max}, mínimo {min}')
# Out:
# Los valores de la provincia de Granada son:
# media = 30217.85, mediana = 17526.0, desviación estándar = 50355.49171459276, máximo = 239154.0, mínimo 10386.0

# %% [markdown]
# # 6) Realice un histograma con la población de los Municipios para cada una de las provincias.

# %%
import pandas as pd
import matplotlib.pyplot as plt

#agrupamos nuestros datos por provincia
provincias = dataset['Provincia'].unique() #utilizamos unique para traer solo valores unicos

# Crear una figura
plt.figure(figsize=(12, 8))

# Iterar sobre cada provincia y crear un histograma para cada una
for provincia in provincias:
    # Filtrar los municipios de la provincia
    municipios_ = dataset[dataset['Provincia'] == provincia]

#Creamos nuestro histograma
    plt.hist(municipios_['Poblacion'],bins=20, alpha=0.5, label=provincia)

# Personalizar el gráfico
plt.title('Histograma de la Población de los Municipios por Provincia')
plt.xlabel('Población')
plt.ylabel('Número de Municipios')
plt.legend(title='Provincias')
plt.grid(True)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7) Seleccione al azar cincuenta municipios diferentes de entre los diponibles en el archivo. Asegúrese de que no se repitan. ¿Luego calcule el promedio de la población y la desviación estándar de esto 50 municipios?.

# %%
import pandas as pd 

#seleccionamos aleatoriamente 50 municipios sin que se repitan
municipios = dataset.sample(n=50, replace=False)

#calculamos el promedio de la poblacion dada la muestra
promedio = municipios['Poblacion'].mean()

#calculamos la desviación estándar dada la muestra
desv = municipios['Poblacion'].std()

#mostramos el resultado
print(f'El promedio de los 50 municipios es: {promedio}')
print(f'La desviación estándar de los 50 municipios es: {desv}')
# Out:
# El promedio de los 50 municipios es: 49961.74
# La desviación estándar de los 50 municipios es: 124549.43197550447

# %% [markdown]
# # 8) Dígame los nombres de los Municipios más cercano y más lejano a Madrid. Para ello debe calcular la distancia en todos ellos y Madrid. No considere a Madrid en el análisis ya que la distancia sería cero.

# %%
import pandas as pd
import numpy as np

#extraemos del dataset el municipio de madrid
madrid = dataset[dataset["Municipio"] == 'Madrid']

#Extraemos las coordenadas
coordenadax = madrid['X']
coordenaday = madrid['Y']

#generamos la funcion para calcular la distancia 
coordenada_municipio = dataset[['X', 'Y']].values

#excluimos a madrid del dataset
madrid_no =dataset[dataset['Municipio'] != 'Madrid']

#calculamos la distancia 
# Función para calcular la distancia usando la fórmula de Haversine
def haversine(lat1, lon1, lat2, lon2):
    # Radio de la Tierra en kilómetros
    R = 6371.0
    
    # Convertir grados a radianes
    lat1_rad = np.radians(lat1)
    lon1_rad = np.radians(lon1)
    lat2_rad = np.radians(lat2)
    lon2_rad = np.radians(lon2)
    
    # Diferencias de latitudes y longitudes
    dlat = lat2_rad - lat1_rad
    dlon = lon2_rad - lon1_rad
    
    # Fórmula de Haversine
    a = np.sin(dlat / 2)**2 + np.cos(lat1_rad) * np.cos(lat2_rad) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    
    # Distancia en kilómetros
    distance = R * c
    return distance
#calculamos la distancia de cada municipio
madrid_no['Distancia_madrid'] = madrid_no.apply(lambda row: haversine(coordenadax, coordenaday, row['X'], row['Y']), axis=1)

#Buscamos el municipio mas cercano a madrid
municipio_cercano = madrid_no.loc[madrid_no['Distancia_madrid'].idxmin()]
municipio_mas_lejano = madrid_no.loc[madrid_no['Distancia_madrid'].idxmax()]

#imprimimos el resultado
print(f"El municipio más cercano a madrid es: {municipio_cercano['Municipio']} con una distancia de {municipio_cercano['Distancia_madrid']:.2f} km")
print(f"El municipio más lejano a madrid es: {municipio_mas_lejano['Municipio']} con una distancia de {municipio_mas_lejano['Distancia_madrid']:.2f} km")
# Out:
# El municipio más cercano a madrid es: Pozuelo de Alarcón con una distancia de 9.00 km
# El municipio más lejano a madrid es: Los Llanos de Aridane con una distancia de 2033.84 km
# C:\Users\Jennifer Tobar\AppData\Local\Temp\ipykernel_42916\3969034539.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   madrid_no['Distancia_madrid'] = madrid_no.apply(lambda row: haversine(coordenadax, coordenaday, row['X'], row['Y']), axis=1)
